# %% [markdown]
# <a href="https://colab.research.google.com/github/Samarth101/ML_Research/blob/main/yolo_training_after_enhancement_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics -q
from ultralytics import YOLO
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.1 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !cp -r "/content/drive/MyDrive/yolo_dataset" "/content/"

# %%
def train_enhanced_yolo():
    print("training YOLO on fully gan enhanced dataset...")
    checkpoint_path="/content/drive/MyDrive/Night_Owl_Project/exdark_enhanced_110/weights/last.pt"

    # model = YOLO('yolov8n.pt')
    model=YOLO(checkpoint_path)

    # results = model.train(
    #     data='/content/data_full_enhanced.yaml',
    #     epochs=50,
    #     imgsz=640,
    #     batch=16,
    #     device=0,
    #     project='/content/drive/MyDrive/Night_Owl_Project',
    #     name='exdark_enhanced_1',
    #     plots=True
    # )

    # just for resuming training as in one session training couldnt possible
    model.train(resume=True)

# %%
if __name__=="__main__":
    train_enhanced_yolo()
# Out:
# training YOLO on fully gan enhanced dataset...
# Ultralytics 8.4.24 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
