# %%
from ultralytics import YOLO

# %%
model=YOLO("yolov8n.pt")

# %%
results=model.train(
    data="data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    device="mps",
    project="Night_Owl_Runs",
    name="exdark_baseline_1",
    plots=True
)
# Out:
# Ultralytics 8.4.19 🚀 Python-3.11.9 torch-2.9.1 MPS (Apple M3)
# ...
